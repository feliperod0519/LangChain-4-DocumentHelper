# %% [markdown]
# <a href="https://colab.research.google.com/github/feliperod0519/LangChain-4-DocumentHelper/blob/main/lab1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install langchain-tavily certifi
# !pip install rich pandas

# %%
import asyncio
import os
import ssl
from typing import Any,Dict,List
import json
from datetime import datetime

import certifi

from langchain_tavily import TavilyExtract, TavilyMap

from rich.console import Console
from rich.table import Table
from rich.panel import Panel
from rich.progress import Progress

ssl_context = ssl.create_default_context(cafile=certifi.where())
os.environ["SSL_CERT_FILE"] = certifi.where()
os.environ["REQUEST_CA_BUNDLE"] = certifi.where()

console = Console()
print("All imports successful")
# Out:
# All imports successful

# %%
import os
os.environ["TAVILY_API_KEY"] = "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"

# %%
tavily_map = TavilyMap(max_depth=3,max_breadth=15,limit=500)
print("TavilyMap initialized")
# Out:
# TavilyMap initialized

# %%
demo_url = "https://python.langchain.com/docs/introduction"
console.log(f"{demo_url}",style="bold blue")
site_map = tavily_map.invoke(demo_url)
urls = site_map.get('results',[])
console.print(f"\nDicovered url",style="bold yellow")
for i,url in enumerate(urls[:50],1):
  console.print(f"{i:2d},{url}")
if len(urls)>10:
  console.print(f"... and {len(urls)-50} more urls")
# Out:
# [03:02:35] https://python.langchain.com/docs/introduction                              ]8;id=308416;file:///tmp/ipython-input-214873250.py\ipython-input-214873250.py]8;;\:]8;id=949462;file:///tmp/ipython-input-214873250.py#2\2]8;;\
# Dicovered url
#  1,https://docs.langchain.com/oss/python/langchain/overview
#  2,https://docs.langchain.com/oss/python/langchain/quickstart
#  3,https://docs.langchain.com/oss/python/langchain/messages
#  4,https://docs.langchain.com/oss/python/langgraph/overview
#  5,https://docs.langchain.com/langsmith/home
#  6,https://www.githubstatus.com/
#  7,https://github.com/git-guides
#  8,https://services.github.com/
#  9,https://desktop.github.com/
# 10,https://github.com/langchain-ai
# 11,https://github.com/newsroom
# 12,https://langchain-ai.github.io/langgraph
# 13,https://github.com/pricing
# 14,https://github.blog/
# 15,https://forum.langchain.com/
# 16,https://partner.github.com/
# 17,https://langchain.com/about
# 18,https://docs.github.com/
# ...

# %%
tavily_extract = TavilyExtract()
print("TavilyExtract initialized!")
# Out:
# TavilyExtract initialized!

# %%
sample_urls = [urls[20]]
console.print(f"Extracting content from {len(sample_urls)}", style="bold blue")
extraction_result = await tavily_extract.ainvoke(input={"urls": sample_urls})
extracted_docs = extraction_result.get('results',[])
console.log(f"\nSuccesfully extracted {len(extracted_docs)} documents", style="bold green")
for i,doc in enumerate(extracted_docs,1):
  url = doc.get('url','unknown')
  content = doc.get('raw_content','')
  panel_content = f"""URL: {url}
Content Length: {len(content):,} characters
Preview: {content}... """
console.print(Panel(panel_content,title=f"Document {i}", border_style="blue"))
print()
# Out:
# Extracting content from 1
# [03:16:46]                                                                            ]8;id=367153;file:///tmp/ipython-input-3801831529.py\ipython-input-3801831529.py]8;;\:]8;id=78510;file:///tmp/ipython-input-3801831529.py#5\5]8;;\
#            Succesfully extracted 1 documents
# ╭────────────────────────────────────────────────── Document 1 ───────────────────────────────────────────────────╮
# │ URL: https://support.github.com/                                                                                │
# │ Content Length: 2,142 characters                                                                                │
# │ Preview: Sign in for Software Support and Product Help - GitHub Support                                         │
# │                                                                                                                 │
# ...
